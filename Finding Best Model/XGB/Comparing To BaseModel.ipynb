# %%
#compare to a base model
import pandas as pd
import numpy as np

# %%
#data
dataset = pd.read_csv('/home/kate/data/ClaimPrediction/fdata_v1_encd.csv', index_col=None)
target_column = 'hasclaim'

# %%
#models and analyzing results directory
ModelsDir='/home/kate/data/ClaimPrediction/s11_BestModelsNewParams/'

# %%
#comparing model metrics with t-test
#and save results
import scipy.stats as stats
def AnalyzeAndSaveModelsResults(result_df,result_lst,ModelName,filename):
    df=pd.DataFrame([result_lst])
    TestSizeColumns=['S0.45','S0.4','S0.35','S0.3','S0.25','S0.2','S0.15','S0.1']
    #TestSizeColumns=['S0.2','S0.15','S0.1']
    df.columns=['Model']+TestSizeColumns
    #mean
    df['Mean'] = df.drop('Model', axis=1).mean(axis=1)
    df['t-pvalue'] = 1
    df['t-statistic'] = 0
    df['Group'] = 1
    #t-test with base model
    if ModelName!='BaseModel':
        base_model=result_df[result_df['Model'] == 'BaseModel'].iloc[0]
        current_model=df.iloc[0]
        t=stats.ttest_ind(base_model[TestSizeColumns].tolist(),current_model[TestSizeColumns].tolist())
        line_to_save=[current_model['Model']]
        line_to_save.extend(current_model[TestSizeColumns].tolist())
        line_to_save.append(current_model[TestSizeColumns].mean())
        line_to_save.append(t.pvalue)
        line_to_save.append(t.statistic)
        if ((t.pvalue<=0.05) and (base_model['Mean']<current_model['Mean'])):
            line_to_save.append(2)
        elif ((t.pvalue<=0.05) and (base_model['Mean']>current_model['Mean'])):
            line_to_save.append(3)    
        else:
            line_to_save.append(1)                  
        df_to_save=pd.DataFrame([line_to_save])
        df_to_save.columns=['Model']+TestSizeColumns+['Mean','t-pvalue','t-statistic','Group']
        result_df=result_df.append(df_to_save, ignore_index=True)
    else:
        result_df=result_df.append(df, ignore_index=True)
    result_df.to_csv(ModelsDir+filename, index = False)
    return result_df

# %%
#xgb library and parameters to tune later
import xgboost as xgb
xgb_params = {'eta': 0.02, 'max_depth': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 
          'objective': 'binary:logistic', 'eval_metric': 'auc', 'silent': True}

# %%
#Evaluation metric to be used in tuning
from sklearn.metrics import roc_auc_score
def gini(y, pred):
    g = np.asarray(np.c_[y, pred, np.arange(len(y)) ], dtype=np.float)
    g = g[np.lexsort((g[:,2], -1*g[:,1]))]
    gs = g[:,0].cumsum().sum() / g[:,0].sum()
    gs -= (len(y) + 1) / 2.
    return gs / len(y)
def gini_xgb(pred, y):
    y = y.get_label()
    return 'gini', gini(y, pred) / gini(y, y)

# %%
#Random Undersampler to balance the dataset
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
#ratio=0.918 to tune later

# %%
#StratifiedKFold
from sklearn.model_selection import StratifiedKFold
nrounds=5000 # need to change to 2000
kfold = 10  # need to change to 10
skf = StratifiedKFold(n_splits=kfold, random_state=42)

# %%
#splitting to train/test in the loop below
from sklearn.model_selection import train_test_split

# %%
#each line in the file contains the model name and set of features to analize
models = pd.read_csv(ModelsDir+'Models.csv', index_col=None)

# %%
#summary for test and train metrics for each model to test overfitting
models_test_gini_df=pd.DataFrame()
models_test_roc_auc_df=pd.DataFrame()
#
models_train_gini_df=pd.DataFrame()
models_train_roc_auc_df=pd.DataFrame()
#
base_model_df=pd.DataFrame()

# %%
for index, row in models.iterrows():
    #for test and train metrics for each model to test overfitting
    gini_test_lst=[]
    roc_auc_test_lst=[]
    gini_train_lst=[]
    roc_auc_train_lst=[]
    #Starting analyzing metric
    print (index, ': Analyzing model %s'%row['Model'])
    gini_test_lst.append(row['Model'])
    roc_auc_test_lst.append(row['Model'])
    gini_train_lst.append(row['Model'])
    roc_auc_train_lst.append(row['Model'])
    featureset=row[1:51].tolist()
    featureset=[x for x in featureset if str(x) != 'nan']
    #calculating metrics for the current featureset and 
    #several data sizes
    for s in (0.45,0.4,0.35,0.3,0.25,0.2,0.15,0.1):
    #for s in (0.2,0.15,0.1):
        print ('Test size %s'%s)
        X, X_test, y, y_test = train_test_split(dataset.loc[:,featureset], dataset[target_column], test_size=s, random_state=42)
        print('--------------------------------------------------------------------')
        print(row['Model'])
        print(len(X.columns))
        print(X.columns)
        print('--------------------------------------------------------------------')
        #prediction dataframes
        y_pred_test=pd.DataFrame(index=y_test.index)
        y_pred_test[target_column]=0
        y_pred_train=pd.DataFrame(index=y.index)
        y_pred_train[target_column]=0
        #
        X = X.values
        y = y.values
        #Stratified Fold
        for i, (train_index, test_index) in enumerate(skf.split(X, y)):
            print(' xgb kfold: {}  of  {} : '.format(i+1, kfold))
            #getting fold data
            X_train, X_valid = X[train_index], X[test_index]
            y_train, y_valid = y[train_index], y[test_index]
            #balancing dataset
            X_res, y_res = rus.fit_sample(X_train, y_train)
            #applying XGB
            d_train = xgb.DMatrix(X_res, y_res) 
            d_valid = xgb.DMatrix(X_valid, y_valid) 
            watchlist = [(d_train, 'train'), (d_valid, 'valid')]
            xgb_model = xgb.train(xgb_params, d_train, nrounds, watchlist, early_stopping_rounds=100, 
                          feval=gini_xgb, maximize=True, verbose_eval=1000)
            y_pred_test[target_column] +=  xgb_model.predict(xgb.DMatrix(X_test.values), ntree_limit=xgb_model.best_ntree_limit+50) / (kfold)
            y_pred_train[target_column] += xgb_model.predict(xgb.DMatrix(X), ntree_limit=xgb_model.best_ntree_limit+50) / (kfold)
        #Prediction results
        #test
        print('--------------------------------------------------------------------')
        print(row['Model'])
        print('Test Size %f'%s)
        print(len(X_test.columns))
        print(X_test.columns)
        print('--------------------------------------------------------------------')
        g=gini(y_test,y_pred_test)/gini(y_test,y_test)
        print('Test Gini - %f'%g)
        gini_test_lst.append(g)
        ROC_AUC=roc_auc_score(y_test, y_pred_test)
        print('Test ROC_AUC - %f'%ROC_AUC)
        roc_auc_test_lst.append(ROC_AUC)
        #train
        g=gini(y,y_pred_train)/gini(y,y)
        print('Train Gini - %f'%g)
        gini_train_lst.append(g)
        ROC_AUC=roc_auc_score(y, y_pred_train)
        print('Train ROC_AUC - %f'%ROC_AUC)
        roc_auc_train_lst.append(ROC_AUC)
    #save model analysis results
    models_test_gini_df=AnalyzeAndSaveModelsResults(models_test_gini_df,gini_test_lst,row['Model'],'models_test_gini.csv')
    models_test_roc_auc_df=AnalyzeAndSaveModelsResults(models_test_roc_auc_df,roc_auc_test_lst,row['Model'],'models_test_roc_auc.csv')
    models_train_gini_df=AnalyzeAndSaveModelsResults(models_train_gini_df,gini_train_lst,row['Model'],'models_train_gini.csv')
    models_train_roc_auc_df=AnalyzeAndSaveModelsResults(models_train_roc_auc_df,roc_auc_train_lst,row['Model'],'models_train_roc_auc.csv')
# Out:
# 0 : Analyzing model BaseModel
# Test size 0.45
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.663602	valid-auc:0.626121	train-gini:0.220751	valid-gini:0.252332
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [373]	train-auc:0.796561	valid-auc:0.711483	train-gini:0.593121	valid-gini:0.422964
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.65414	valid-auc:0.629012	train-gini:0.187969	valid-gini:0.247436
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [368]	train-auc:0.795995	valid-auc:0.709871	train-gini:0.591989	valid-gini:0.419744
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.656228	valid-auc:0.62236	train-gini:0.161188	valid-gini:0.225294
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [543]	train-auc:0.818941	valid-auc:0.699872	train-gini:0.63788	valid-gini:0.399743
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.653647	valid-auc:0.636707	train-gini:0.156658	valid-gini:0.272076
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [483]	train-auc:0.815707	valid-auc:0.711921	train-gini:0.631413	valid-gini:0.423843
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.659082	valid-auc:0.635187	train-gini:0.167264	valid-gini:0.268612
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [337]	train-auc:0.794688	valid-auc:0.696555	train-gini:0.589374	valid-gini:0.393112
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.658791	valid-auc:0.631671	train-gini:0.170303	valid-gini:0.278401
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [732]	train-auc:0.843583	valid-auc:0.703199	train-gini:0.687164	valid-gini:0.406399
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.657204	valid-auc:0.635782	train-gini:0.163489	valid-gini:0.28358
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [333]	train-auc:0.791611	valid-auc:0.707373	train-gini:0.58322	valid-gini:0.414746
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.659022	valid-auc:0.591311	train-gini:0.172207	valid-gini:0.200231
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [235]	train-auc:0.776175	valid-auc:0.673708	train-gini:0.552348	valid-gini:0.347415
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.64685	valid-auc:0.633491	train-gini:0.172394	valid-gini:0.289524
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [213]	train-auc:0.771165	valid-auc:0.708665	train-gini:0.542328	valid-gini:0.417331
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.655563	valid-auc:0.628375	train-gini:0.223946	valid-gini:0.266797
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [296]	train-auc:0.790102	valid-auc:0.688879	train-gini:0.580202	valid-gini:0.377758
#
# --------------------------------------------------------------------
# BaseModel
# Test Size 0.450000
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.403727
# Test ROC_AUC - 0.701864
# Train Gini - 0.513471
# Train ROC_AUC - 0.756736
# Test size 0.4
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.654271	valid-auc:0.640893	train-gini:0.18949	valid-gini:0.267627
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [269]	train-auc:0.769088	valid-auc:0.68665	train-gini:0.538176	valid-gini:0.373299
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.651855	valid-auc:0.63335	train-gini:0.187148	valid-gini:0.25175
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [394]	train-auc:0.788749	valid-auc:0.711018	train-gini:0.577498	valid-gini:0.422036
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.649603	valid-auc:0.627144	train-gini:0.159025	valid-gini:0.231092
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [391]	train-auc:0.792263	valid-auc:0.715368	train-gini:0.584526	valid-gini:0.430735
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.654586	valid-auc:0.615485	train-gini:0.211693	valid-gini:0.215567
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [515]	train-auc:0.806657	valid-auc:0.701371	train-gini:0.613314	valid-gini:0.402741
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.645459	valid-auc:0.645138	train-gini:0.187294	valid-gini:0.282889
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [242]	train-auc:0.769747	valid-auc:0.718824	train-gini:0.539494	valid-gini:0.437648
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.647991	valid-auc:0.624633	train-gini:0.163827	valid-gini:0.250088
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [604]	train-auc:0.822493	valid-auc:0.703524	train-gini:0.644984	valid-gini:0.407048
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.641715	valid-auc:0.609419	train-gini:0.150931	valid-gini:0.221967
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [708]	train-auc:0.834184	valid-auc:0.701663	train-gini:0.668367	valid-gini:0.403325
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.644094	valid-auc:0.611697	train-gini:0.131366	valid-gini:0.233113
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [314]	train-auc:0.784018	valid-auc:0.69315	train-gini:0.568034	valid-gini:0.386299
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.644762	valid-auc:0.626006	train-gini:0.149046	valid-gini:0.265784
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [797]	train-auc:0.843078	valid-auc:0.715573	train-gini:0.686155	valid-gini:0.431145
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.641829	valid-auc:0.629586	train-gini:0.146928	valid-gini:0.26731
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [375]	train-auc:0.79417	valid-auc:0.693923	train-gini:0.588338	valid-gini:0.387845
#
# --------------------------------------------------------------------
# BaseModel
# Test Size 0.400000
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.412492
# Test ROC_AUC - 0.706246
# Train Gini - 0.521001
# Train ROC_AUC - 0.760501
# Test size 0.35
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.648482	valid-auc:0.633458	train-gini:0.170268	valid-gini:0.268225
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [501]	train-auc:0.800235	valid-auc:0.710145	train-gini:0.600469	valid-gini:0.42029
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.656898	valid-auc:0.627183	train-gini:0.220195	valid-gini:0.240138
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [615]	train-auc:0.813849	valid-auc:0.689962	train-gini:0.627697	valid-gini:0.379924
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.654982	valid-auc:0.640297	train-gini:0.198048	valid-gini:0.261915
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [375]	train-auc:0.785802	valid-auc:0.709148	train-gini:0.571602	valid-gini:0.418295
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.646879	valid-auc:0.634389	train-gini:0.167517	valid-gini:0.245968
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [298]	train-auc:0.776925	valid-auc:0.709559	train-gini:0.553848	valid-gini:0.419117
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.648395	valid-auc:0.619217	train-gini:0.193452	valid-gini:0.226469
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [387]	train-auc:0.789777	valid-auc:0.713353	train-gini:0.579553	valid-gini:0.426706
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.65402	valid-auc:0.624353	train-gini:0.185891	valid-gini:0.239683
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [632]	train-auc:0.816199	valid-auc:0.710896	train-gini:0.632398	valid-gini:0.421792
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.650838	valid-auc:0.631225	train-gini:0.191215	valid-gini:0.269038
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [346]	train-auc:0.785918	valid-auc:0.705569	train-gini:0.571836	valid-gini:0.411139
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.651305	valid-auc:0.60008	train-gini:0.201633	valid-gini:0.205654
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [238]	train-auc:0.767587	valid-auc:0.690767	train-gini:0.535172	valid-gini:0.381534
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.646723	valid-auc:0.609962	train-gini:0.166379	valid-gini:0.231795
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [484]	train-auc:0.798195	valid-auc:0.70047	train-gini:0.596388	valid-gini:0.400941
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.650215	valid-auc:0.628721	train-gini:0.204838	valid-gini:0.26276
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [580]	train-auc:0.807048	valid-auc:0.701619	train-gini:0.614094	valid-gini:0.403238
#
# --------------------------------------------------------------------
# BaseModel
# Test Size 0.350000
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.415355
# Test ROC_AUC - 0.707677
# Train Gini - 0.513291
# Train ROC_AUC - 0.756646
# Test size 0.3
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.650614	valid-auc:0.626301	train-gini:0.181398	valid-gini:0.256379
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [674]	train-auc:0.825115	valid-auc:0.716166	train-gini:0.650229	valid-gini:0.432331
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.650878	valid-auc:0.633792	train-gini:0.186444	valid-gini:0.263082
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [370]	train-auc:0.789266	valid-auc:0.697406	train-gini:0.57853	valid-gini:0.394812
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.649502	valid-auc:0.63937	train-gini:0.185402	valid-gini:0.264148
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [236]	train-auc:0.772073	valid-auc:0.706314	train-gini:0.544145	valid-gini:0.412628
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.641521	valid-auc:0.643097	train-gini:0.151089	valid-gini:0.268602
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [281]	train-auc:0.769546	valid-auc:0.708312	train-gini:0.53909	valid-gini:0.416623
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.642721	valid-auc:0.627357	train-gini:0.153988	valid-gini:0.235314
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [466]	train-auc:0.793955	valid-auc:0.70933	train-gini:0.587908	valid-gini:0.418661
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.643114	valid-auc:0.641027	train-gini:0.179576	valid-gini:0.275622
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [340]	train-auc:0.778994	valid-auc:0.719666	train-gini:0.557987	valid-gini:0.439333
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.646912	valid-auc:0.605213	train-gini:0.188162	valid-gini:0.212153
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [652]	train-auc:0.817537	valid-auc:0.704197	train-gini:0.635074	valid-gini:0.408395
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.642729	valid-auc:0.629389	train-gini:0.167124	valid-gini:0.259842
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [401]	train-auc:0.786565	valid-auc:0.709709	train-gini:0.573128	valid-gini:0.419416
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.633891	valid-auc:0.611291	train-gini:0.032403	valid-gini:0.254509
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [473]	train-auc:0.796708	valid-auc:0.69487	train-gini:0.593415	valid-gini:0.389738
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.642748	valid-auc:0.623569	train-gini:0.175797	valid-gini:0.25638
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [339]	train-auc:0.780357	valid-auc:0.693362	train-gini:0.560714	valid-gini:0.386724
#
# --------------------------------------------------------------------
# BaseModel
# Test Size 0.300000
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.409091
# Test ROC_AUC - 0.704546
# Train Gini - 0.508039
# Train ROC_AUC - 0.754020
# Test size 0.25
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.643646	valid-auc:0.627602	train-gini:0.164226	valid-gini:0.269242
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [327]	train-auc:0.772274	valid-auc:0.704028	train-gini:0.544546	valid-gini:0.408057
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.650713	valid-auc:0.619973	train-gini:0.19632	valid-gini:0.262082
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [603]	train-auc:0.803244	valid-auc:0.705971	train-gini:0.606486	valid-gini:0.411942
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.649212	valid-auc:0.631037	train-gini:0.191414	valid-gini:0.267724
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [374]	train-auc:0.777408	valid-auc:0.692359	train-gini:0.554814	valid-gini:0.384718
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.651274	valid-auc:0.659666	train-gini:0.218861	valid-gini:0.319784
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [467]	train-auc:0.788731	valid-auc:0.723976	train-gini:0.57746	valid-gini:0.447952
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.646607	valid-auc:0.621465	train-gini:0.125192	valid-gini:0.23492
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [404]	train-auc:0.781593	valid-auc:0.708545	train-gini:0.563185	valid-gini:0.417091
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.635899	valid-auc:0.629165	train-gini:0.025715	valid-gini:0.266213
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [424]	train-auc:0.786302	valid-auc:0.720229	train-gini:0.572603	valid-gini:0.440457
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.647089	valid-auc:0.62545	train-gini:0.17146	valid-gini:0.258374
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [621]	train-auc:0.808621	valid-auc:0.707601	train-gini:0.617242	valid-gini:0.415202
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.650183	valid-auc:0.622429	train-gini:0.175925	valid-gini:0.254255
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [317]	train-auc:0.773111	valid-auc:0.70645	train-gini:0.546221	valid-gini:0.412899
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.65009	valid-auc:0.612076	train-gini:0.178694	valid-gini:0.239202
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [429]	train-auc:0.786351	valid-auc:0.693902	train-gini:0.572701	valid-gini:0.387802
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.649958	valid-auc:0.623024	train-gini:0.179844	valid-gini:0.257519
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [580]	train-auc:0.803484	valid-auc:0.693544	train-gini:0.606967	valid-gini:0.387087
#
# --------------------------------------------------------------------
# BaseModel
# Test Size 0.250000
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.415305
# Test ROC_AUC - 0.707653
# Train Gini - 0.505959
# Train ROC_AUC - 0.752980
# Test size 0.2
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.643738	valid-auc:0.639697	train-gini:0.164758	valid-gini:0.279206
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [694]	train-auc:0.809176	valid-auc:0.700455	train-gini:0.61835	valid-gini:0.400911
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.64531	valid-auc:0.630569	train-gini:0.169057	valid-gini:0.280354
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [545]	train-auc:0.788126	valid-auc:0.711688	train-gini:0.576251	valid-gini:0.423377
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.645894	valid-auc:0.627121	train-gini:0.181463	valid-gini:0.266858
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [414]	train-auc:0.775728	valid-auc:0.700724	train-gini:0.551455	valid-gini:0.401449
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.642161	valid-auc:0.621598	train-gini:0.156401	valid-gini:0.245907
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [506]	train-auc:0.787736	valid-auc:0.703829	train-gini:0.57547	valid-gini:0.407657
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.645692	valid-auc:0.626907	train-gini:0.143669	valid-gini:0.244125
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [346]	train-auc:0.766716	valid-auc:0.711055	train-gini:0.533432	valid-gini:0.422111
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.646532	valid-auc:0.627807	train-gini:0.193482	valid-gini:0.255506
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [448]	train-auc:0.777668	valid-auc:0.716926	train-gini:0.555335	valid-gini:0.433852
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.636407	valid-auc:0.631012	train-gini:0.144788	valid-gini:0.268971
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [775]	train-auc:0.80913	valid-auc:0.716068	train-gini:0.61826	valid-gini:0.432136
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.633477	valid-auc:0.627283	train-gini:0.133116	valid-gini:0.264462
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [466]	train-auc:0.781475	valid-auc:0.705602	train-gini:0.562949	valid-gini:0.411204
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.635322	valid-auc:0.626437	train-gini:0.140063	valid-gini:0.269423
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [418]	train-auc:0.778285	valid-auc:0.691525	train-gini:0.556569	valid-gini:0.383048
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.633818	valid-auc:0.614112	train-gini:0.109703	valid-gini:0.241904
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [237]	train-auc:0.755104	valid-auc:0.698204	train-gini:0.510207	valid-gini:0.396406
#
# --------------------------------------------------------------------
# BaseModel
# Test Size 0.200000
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.425068
# Test ROC_AUC - 0.712534
# Train Gini - 0.506229
# Train ROC_AUC - 0.753114
# Test size 0.15
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.640518	valid-auc:0.638094	train-gini:0.156739	valid-gini:0.262534
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [475]	train-auc:0.780632	valid-auc:0.702432	train-gini:0.561262	valid-gini:0.404863
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.641513	valid-auc:0.634651	train-gini:0.148943	valid-gini:0.269953
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [361]	train-auc:0.767743	valid-auc:0.704704	train-gini:0.535485	valid-gini:0.409408
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.643569	valid-auc:0.605484	train-gini:0.137768	valid-gini:0.227964
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [525]	train-auc:0.78565	valid-auc:0.713211	train-gini:0.571298	valid-gini:0.426422
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.640409	valid-auc:0.642646	train-gini:0.135093	valid-gini:0.283153
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [393]	train-auc:0.775765	valid-auc:0.701437	train-gini:0.551529	valid-gini:0.402874
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.639979	valid-auc:0.634703	train-gini:0.162929	valid-gini:0.259778
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [349]	train-auc:0.77044	valid-auc:0.707792	train-gini:0.540878	valid-gini:0.415585
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.641124	valid-auc:0.638375	train-gini:0.172366	valid-gini:0.269152
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [691]	train-auc:0.80562	valid-auc:0.727438	train-gini:0.611239	valid-gini:0.454877
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.656109	valid-auc:0.65812	train-gini:0.218358	valid-gini:0.315326
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [301]	train-auc:0.76921	valid-auc:0.713698	train-gini:0.538419	valid-gini:0.427395
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.649162	valid-auc:0.632126	train-gini:0.201171	valid-gini:0.268752
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [589]	train-auc:0.801228	valid-auc:0.713257	train-gini:0.602454	valid-gini:0.426514
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.648454	valid-auc:0.631287	train-gini:0.197839	valid-gini:0.271442
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [333]	train-auc:0.772852	valid-auc:0.696691	train-gini:0.545702	valid-gini:0.393381
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.648086	valid-auc:0.628776	train-gini:0.195336	valid-gini:0.265228
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [557]	train-auc:0.796924	valid-auc:0.702686	train-gini:0.593847	valid-gini:0.405371
#
# --------------------------------------------------------------------
# BaseModel
# Test Size 0.150000
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
#        'passiveseatbeltind_encd', 'viol_driverpointsnumbercountterm',
#        'antitheftcd_encd', 'restraintcd_encd', 'programtypecd_encd',
#        'persontypecd_encd', 'viol_last_convictionage',
#        'viol_last_infractionage', 'havelicenseage', 'enginehorsepower',
#        'daylightrunninglightsind_encd'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.418854
# Test ROC_AUC - 0.709427
# Train Gini - 0.501997
# Train ROC_AUC - 0.750999
# Test size 0.1
# --------------------------------------------------------------------
# BaseModel
# 50
# Index(['driverage', 'classcd_encd', 'vehicleage', 'mvrstatusage',
#        'mvrstatus_encd', 'drivernumber', 'carpoolind_encd',
#        'relationshiptoinsuredcd_encd', 'gooddriverind_encd',
#        'accidentpreventioncourseind_encd', 'drivertrainingind_encd',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'ratingvalue',
#        'vehnumber', 'maturedriverind_encd', 'driverstatuscd_encd',
#        'estimatedannualdistance', 'daysperweekdriven',
#        'acci_pointschargedterm', 'maritalstatuscd_encd', 'odometerreading',
#        'licensedstateprovcd_encd', 'enginecylinders_encd', 'model_encd',
#        'acci_last_infractionage', 'acci_infractioncdcountterm',
#        'gendercd_encd', 'occupationclasscd_encd',
#        'acci_driverpointsnumbercountterm', 'garageterritory',
#        'manufacturer_encd', 'acci_last_convictionage', 'performancecd_encd',
#        'registrationstateprovcd_encd', 'enginesize', 'vehusecd_encd',
#        'viol_pointschargedterm', 'viol_infractioncdcountterm',
# ...
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.650712	valid-auc:0.624412	train-gini:0.216082	valid-gini:0.263694
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [486]	train-auc:0.753801	valid-auc:0.702373	train-gini:0.5076	valid-gini:0.404748
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.648986	valid-auc:0.637195	train-gini:0.204331	valid-gini:0.28464
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [599]	train-auc:0.761204	valid-auc:0.698953	train-gini:0.522406	valid-gini:0.397907
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.647767	valid-auc:0.629074	train-gini:0.213887	valid-gini:0.259898
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [837]	train-auc:0.775349	valid-auc:0.696766	train-gini:0.550697	valid-gini:0.393531
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.645337	valid-auc:0.626698	train-gini:0.205768	valid-gini:0.247234
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [446]	train-auc:0.750235	valid-auc:0.703912	train-gini:0.500466	valid-gini:0.407823
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.642476	valid-auc:0.640707	train-gini:0.174026	valid-gini:0.278991
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [383]	train-auc:0.744812	valid-auc:0.699747	train-gini:0.489621	valid-gini:0.399493
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.641599	valid-auc:0.6399	train-gini:0.179478	valid-gini:0.283897
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [418]	train-auc:0.745508	valid-auc:0.702388	train-gini:0.491013	valid-gini:0.404776
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.643875	valid-auc:0.627553	train-gini:0.179887	valid-gini:0.264382
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [309]	train-auc:0.737953	valid-auc:0.693341	train-gini:0.475902	valid-gini:0.386683
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.643458	valid-auc:0.609963	train-gini:0.173446	valid-gini:0.232696
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [699]	train-auc:0.767113	valid-auc:0.684195	train-gini:0.534224	valid-gini:0.368388
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.642503	valid-auc:0.630973	train-gini:0.181397	valid-gini:0.270976
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [364]	train-auc:0.744938	valid-auc:0.696563	train-gini:0.489871	valid-gini:0.393126
#
# --------------------------------------------------------------------
# ShortBestModel1
# Test Size 0.200000
# 14
# Index(['acci_last_infractionage', 'accidentpreventioncourseind_encd',
#        'carpoolind_encd', 'classcd_encd', 'driverage', 'drivernumber',
#        'drivertrainingind_encd', 'gooddriverind_encd', 'mvrstatus_encd',
#        'mvrstatusage', 'ratingvalue', 'scholasticdiscountind_encd',
#        'vehbodytypecd_encd', 'vehicleage'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.416451
# Test ROC_AUC - 0.708226
# Train Gini - 0.460475
# Train ROC_AUC - 0.730238
# Test size 0.15
# --------------------------------------------------------------------
# ShortBestModel1
# 14
# Index(['acci_last_infractionage', 'accidentpreventioncourseind_encd',
#        'carpoolind_encd', 'classcd_encd', 'driverage', 'drivernumber',
#        'drivertrainingind_encd', 'gooddriverind_encd', 'mvrstatus_encd',
#        'mvrstatusage', 'ratingvalue', 'scholasticdiscountind_encd',
#        'vehbodytypecd_encd', 'vehicleage'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.64042	valid-auc:0.628878	train-gini:0.165217	valid-gini:0.246562
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [348]	train-auc:0.738311	valid-auc:0.700567	train-gini:0.476618	valid-gini:0.401133
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.645132	valid-auc:0.636493	train-gini:0.184926	valid-gini:0.27417
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [337]	train-auc:0.739607	valid-auc:0.697643	train-gini:0.47921	valid-gini:0.395287
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.647364	valid-auc:0.614117	train-gini:0.158205	valid-gini:0.242343
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [511]	train-auc:0.752586	valid-auc:0.706977	train-gini:0.50517	valid-gini:0.413955
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.644314	valid-auc:0.641958	train-gini:0.175401	valid-gini:0.2796
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [303]	train-auc:0.741961	valid-auc:0.690435	train-gini:0.483917	valid-gini:0.380871
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.642899	valid-auc:0.639218	train-gini:0.16388	valid-gini:0.268249
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [273]	train-auc:0.738226	valid-auc:0.698771	train-gini:0.47644	valid-gini:0.397546
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.645229	valid-auc:0.63492	train-gini:0.164556	valid-gini:0.257456
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [564]	train-auc:0.759645	valid-auc:0.712936	train-gini:0.519288	valid-gini:0.425871
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.654796	valid-auc:0.649182	train-gini:0.204313	valid-gini:0.298705
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [331]	train-auc:0.750378	valid-auc:0.698327	train-gini:0.500749	valid-gini:0.396654
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.650081	valid-auc:0.632693	train-gini:0.185593	valid-gini:0.272222
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [357]	train-auc:0.751668	valid-auc:0.701776	train-gini:0.503333	valid-gini:0.403553
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.646743	valid-auc:0.620108	train-gini:0.176473	valid-gini:0.249717
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [285]	train-auc:0.743623	valid-auc:0.686746	train-gini:0.487236	valid-gini:0.373492
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.646697	valid-auc:0.619385	train-gini:0.177195	valid-gini:0.24653
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [473]	train-auc:0.756819	valid-auc:0.693909	train-gini:0.513635	valid-gini:0.387818
#
# --------------------------------------------------------------------
# ShortBestModel1
# Test Size 0.150000
# 14
# Index(['acci_last_infractionage', 'accidentpreventioncourseind_encd',
#        'carpoolind_encd', 'classcd_encd', 'driverage', 'drivernumber',
#        'drivertrainingind_encd', 'gooddriverind_encd', 'mvrstatus_encd',
#        'mvrstatusage', 'ratingvalue', 'scholasticdiscountind_encd',
#        'vehbodytypecd_encd', 'vehicleage'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.414629
# Test ROC_AUC - 0.707315
# Train Gini - 0.452361
# Train ROC_AUC - 0.726180
# Test size 0.1
# --------------------------------------------------------------------
# ShortBestModel1
# 14
# Index(['acci_last_infractionage', 'accidentpreventioncourseind_encd',
#        'carpoolind_encd', 'classcd_encd', 'driverage', 'drivernumber',
#        'drivertrainingind_encd', 'gooddriverind_encd', 'mvrstatus_encd',
#        'mvrstatusage', 'ratingvalue', 'scholasticdiscountind_encd',
#        'vehbodytypecd_encd', 'vehicleage'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# [0]	train-auc:0.651494	valid-auc:0.642487	train-gini:0.205329	valid-gini:0.278619
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [418]	train-auc:0.750128	valid-auc:0.706523	train-gini:0.500254	valid-gini:0.413045
#
#  xgb kfold: 2  of  10 :
# [0]	train-auc:0.645138	valid-auc:0.638848	train-gini:0.191726	valid-gini:0.267764
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [331]	train-auc:0.743059	valid-auc:0.697262	train-gini:0.486115	valid-gini:0.394524
#
#  xgb kfold: 3  of  10 :
# [0]	train-auc:0.640373	valid-auc:0.626956	train-gini:0.161156	valid-gini:0.260595
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [526]	train-auc:0.7549	valid-auc:0.702381	train-gini:0.509798	valid-gini:0.404761
#
#  xgb kfold: 4  of  10 :
# [0]	train-auc:0.645139	valid-auc:0.62971	train-gini:0.190857	valid-gini:0.26068
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [751]	train-auc:0.769181	valid-auc:0.696999	train-gini:0.538361	valid-gini:0.393999
#
#  xgb kfold: 5  of  10 :
# [0]	train-auc:0.642302	valid-auc:0.643677	train-gini:0.169983	valid-gini:0.279387
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [616]	train-auc:0.759106	valid-auc:0.704118	train-gini:0.518211	valid-gini:0.408235
#
#  xgb kfold: 6  of  10 :
# [0]	train-auc:0.649464	valid-auc:0.648935	train-gini:0.204749	valid-gini:0.288311
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [361]	train-auc:0.739884	valid-auc:0.703834	train-gini:0.479764	valid-gini:0.407669
#
#  xgb kfold: 7  of  10 :
# [0]	train-auc:0.646045	valid-auc:0.644931	train-gini:0.194169	valid-gini:0.287206
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [492]	train-auc:0.749656	valid-auc:0.697136	train-gini:0.49931	valid-gini:0.394271
#
#  xgb kfold: 8  of  10 :
# [0]	train-auc:0.653228	valid-auc:0.635079	train-gini:0.223543	valid-gini:0.271748
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [426]	train-auc:0.749484	valid-auc:0.693031	train-gini:0.498966	valid-gini:0.386063
#
#  xgb kfold: 9  of  10 :
# [0]	train-auc:0.654996	valid-auc:0.622587	train-gini:0.219012	valid-gini:0.250656
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [412]	train-auc:0.745788	valid-auc:0.687288	train-gini:0.491571	valid-gini:0.374577
#
#  xgb kfold: 10  of  10 :
# [0]	train-auc:0.651648	valid-auc:0.653672	train-gini:0.213923	valid-gini:0.313348
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# Stopping. Best iteration:
# [657]	train-auc:0.75904	valid-auc:0.69763	train-gini:0.518077	valid-gini:0.395259
#
# --------------------------------------------------------------------
# ShortBestModel1
# Test Size 0.100000
# 14
# Index(['acci_last_infractionage', 'accidentpreventioncourseind_encd',
#        'carpoolind_encd', 'classcd_encd', 'driverage', 'drivernumber',
#        'drivertrainingind_encd', 'gooddriverind_encd', 'mvrstatus_encd',
#        'mvrstatusage', 'ratingvalue', 'scholasticdiscountind_encd',
#        'vehbodytypecd_encd', 'vehicleage'],
#       dtype='object')
# --------------------------------------------------------------------
# Test Gini - 0.422250
# Test ROC_AUC - 0.711125
# Train Gini - 0.458961
# Train ROC_AUC - 0.729480
# 3 : Analyzing model ShortBestModel2
# Test size 0.45
# --------------------------------------------------------------------
# ShortBestModel2
# 14
# Index(['gendercd', 'accidentpreventioncourseind_encd', 'carpoolind_encd',
#        'classcd_encd', 'driverage', 'drivernumber', 'drivertrainingind_encd',
#        'gooddriverind_encd', 'mvrstatus_encd', 'mvrstatusage', 'ratingvalue',
#        'scholasticdiscountind_encd', 'vehbodytypecd_encd', 'vehicleage'],
#       dtype='object')
# --------------------------------------------------------------------
#  xgb kfold: 1  of  10 :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-4a621e9ff557> in <module>()
#      39             y_train, y_valid = y[train_index], y[test_index]
#      40             #balancing dataset
# ---> 41             X_res, y_res = rus.fit_sample(X_train, y_train)
#      42             #applying XGB
#      43             d_train = xgb.DMatrix(X_res, y_res)
#
# ~/anaconda/lib/python3.6/site-packages/imblearn/base.py in fit_sample(self, X, y)
#      86         """
#      87
# ---> 88         return self.fit(X, y).sample(X, y)
#      89
#      90     @abstractmethod
#
# ~/anaconda/lib/python3.6/site-packages/imblearn/base.py in fit(self, X, y)
#     155
#     156         """
# --> 157         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc'])
#     158         y = check_target_type(y)
#     159         self.X_hash_, self.y_hash_ = hash_X_y(X, y)
#
# ~/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Male'

# %% [markdown]
# Red and Green bars below indicates models where mean of gini is likely different from a previous model

# %%
models_test_gini_df

# %%
models_test_gini_df.set_index('Model', inplace=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
colors = {1: 'blue', 2: 'green',3: 'red'}

# %%
customcmap = tuple(models_test_gini_df['Group'].map(colors))
models_test_gini_df['Mean'].plot(kind='barh',  color=[customcmap], figsize=(10, 12))
